-- %% [markdown]
-- # Advanced Database Systems – Exercise Sheet 2

-- %%
%GUESS_PARSER
%LOAD_TESTS tests.json
%CREATE :memory: OF tables.sql

-- %% [markdown]
-- ---
--
-- ## Task 1
--
-- List and discuss the operators in the relational algebra (RA).

-- %%
-- TODO

-- %% [markdown]
-- ---
--
-- ## Task 2

-- %% [markdown]
-- Consider a database with the following relations.

-- %%
%SCHEMA TD

-- %%
SELECT * FROM Customers;

-- %%
SELECT * FROM Products;

-- %%
SELECT * FROM Sales;

-- %%
SELECT * FROM Stores;

-- %%
SELECT * FROM SpecialOffers;

-- %%
SELECT * FROM Receipts;

-- %% [markdown]
-- ---
--
-- ### Task 2.(a)
--
-- Give a verbal formulation and the result of the following RA expressions.

-- %%
%TEST task-2a-1

π [RNo] (Receipts)

-- %%
%TEST task-2a-2

Customers - π [CNo, Name] (Customers ⋈ Sales)

-- %%
%TEST task-2a-3

π [SID] (Stores) - π [SID] ((π [RNo, SID] (Sales) ⋈ Receipts) ⋈ SpecialOffers)

-- %% [markdown]
-- ---
--
-- ### Task 2.(b)
--
-- Formulate the following queries in RA and SQL.

-- %% [markdown]
-- List all customer names.

-- %%
%TEST task-2b-1

-- TODO: RA

-- %%
%TEST task-2b-1

-- TODO: SQL

-- %% [markdown]
-- List all receipts of sales that took place in the morning by their receipt number.

-- %%
%TEST task-2b-2

-- TODO: RA

-- %%
%TEST task-2b-2

-- TODO: SQL

-- %% [markdown]
-- Which products were bought on "19.10.2025"? List the products based on their description.

-- %%
%TEST task-2b-3

-- TODO: RA

-- %%
%TEST task-2b-3

-- TODO: SQL

-- %% [markdown]
-- List the names of customers together with their purchased products.

-- %%
%TEST task-2b-4

-- TODO: RA

-- %%
%TEST task-2b-4

-- TODO: SQL

-- %% [markdown]
-- Which customers have not bought anything? List the customer numbers and names.

-- %%
%TEST task-2b-5

-- TODO: RA

-- %%
%TEST task-2b-5

-- TODO: SQL

-- %% [markdown]
-- Which stores have the fewest products on sale? List store IDs, names, addresses, and product counts.

-- %%
-- TODO: RA

-- %%
%TEST task-2b-6

-- TODO: SQL

-- %% [markdown]
-- Which store had the earliest sale? List store IDs and names, as well as sales dates and times.

-- %%
%TEST task-2b-7

-- TODO: RA

-- %%
%TEST task-2b-7

-- TODO: SQL

-- %% [markdown]
-- ### Task 2.(c)
--
-- What is the result of a Left Semi-Join and a Right Semi-Join of the relations Customers and Sales? Give a verbal formulation for these expressions.

-- %%
%TEST task-2c-1

-- TODO: Left Semi-Join

-- %%
%TEST task-2c-2

-- TODO: Right Semi-Join

-- %% [markdown]
-- ### Task 2.(d)
--
-- Provide the results of the following RA expressions.

-- %%
%TEST task-2d-1

-- TODO

-- %%
%TEST task-2d-2

-- TODO

-- %%
%TEST task-2d-3

-- TODO
